# %%
# Import necessary libraries
import pandas as pd
from google.colab import drive
import os

drive.mount('/content/drive')


csv_file_path = '/content/drive/MyDrive/preprocessed_telegram_data.csv'

if not os.path.exists(csv_file_path):
    print(f"Error: CSV file not found at {csv_file_path}")
    print("Please ensure the CSV file is in the specified Google Drive path and the path is correct.")
else:
    print(f"CSV file found at {csv_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# CSV file found at /content/drive/MyDrive/preprocessed_telegram_data.csv

# %%
# Load the preprocessed data
try:
    df = pd.read_csv(csv_file_path)
    print("DataFrame loaded successfully!")
    print(f"Total messages: {len(df)}")
    print("First 5 rows of the DataFrame:")
    print(df.head())
except Exception as e:
    print(f"Error loading CSV: {e}")
# Out:
# DataFrame loaded successfully!
# Total messages: 1500
# First 5 rows of the DataFrame:
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7004
# 1  Zemen Express®    @ZemenExpress        7003
# 2  Zemen Express®    @ZemenExpress        7002
# 3  Zemen Express®    @ZemenExpress        7001
# 4  Zemen Express®    @ZemenExpress        7000
#
#                                              Message  \
# 0  Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አ...
#
#                         Date                 Media Path
# 0  2025-06-23 14:55:46+00:00  Photo attached (ID: 7004)
# 1  2025-06-23 14:55:40+00:00  Photo attached (ID: 7003)
# 2  2025-06-23 14:55:40+00:00  Photo attached (ID: 7002)
# 3  2025-06-23 14:55:40+00:00  Photo attached (ID: 7001)
# 4  2025-06-23 14:55:40+00:00  Photo attached (ID: 7000)

# %%
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize

# --- NLTK Data Downloads ---
try:
    # Attempt to download the main 'punkt' tokenizer data
    nltk.download('punkt', quiet=True)
    print("NLTK 'punkt' data downloaded successfully.")
except Exception as e:
    print(f"Error downloading NLTK 'punkt' data: {e}. Please ensure you have an internet connection.")

try:
    # Explicitly download 'punkt_tab' as well, which is sometimes required by word_tokenize
    # especially for certain language models or internal structures.
    nltk.download('punkt_tab', quiet=True)
    print("NLTK 'punkt_tab' data downloaded successfully.")
except Exception as e:
    print(f"Error downloading NLTK 'punkt_tab' data: {e}. Please ensure you have an internet connection.")


labeled_data_conll = []

# Number of messages to label (50)
num_messages_to_label = 50

print(f"\n--- Starting Manual CoNLL Labeling for {num_messages_to_label} Messages ---")
print("Instructions: For each token, provide its CoNLL label (B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O).")
print("Type 'done' when you are finished labeling a message. Type 'skip' to move to the next message.")
print("Example: 'ይህ B-Product ስልክ I-Product 5000 B-PRICE ብር I-PRICE ነው። O'")


try:
    df = pd.read_csv(csv_file_path)
    if 'Message' not in df.columns or 'Message ID' not in df.columns:
        raise ValueError("DataFrame must contain 'Message' and 'Message ID' columns.")
except FileNotFoundError:
    print(f"Error: CSV file not found at '{csv_file_path}'. Please check the path and try again.")
    # Exit or handle the error gracefully if the file isn't found
    exit()
except Exception as e:
    print(f"Error loading CSV or processing DataFrame: {e}")
    exit()

# Iterate through the messages in the DataFrame
for i, message_row in df.head(num_messages_to_label).iterrows():
    message_text = str(message_row['Message']).strip() # Ensure it's a string
    # Get Message ID safely, in case the column name has slight variations
    message_id = message_row.get('Message ID', f"No_ID_{i+1}")

    if not message_text:
        print(f"\nMessage {i+1} (ID: {message_id}): [No text content - Skipping]")
        continue

    print(f"\n--- Message {i+1} (ID: {message_id}) ---")
    print(f"Original Message: {message_text}")

    # Tokenize the message (using NLTK's word_tokenize)
    tokens = word_tokenize(message_text) # Use imported word_tokenize directly

    current_labeled_message = []
    print("\nTokens and their labels:")
    for token in tokens:
        label = input(f"Token: '{token}' -> Label: ").strip()
        while label not in ['B-Product', 'I-Product', 'B-LOC', 'I-LOC', 'B-PRICE', 'I-PRICE', 'O', 'skip', 'done']:
            print("Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done")
            label = input(f"Token: '{token}' -> Label: ").strip()

        if label == 'skip':
            current_labeled_message = [] # Clear any partial labels for this message
            break
        elif label == 'done':
            # This break will exit the inner loop (token labeling for current message)
            # and the current_labeled_message will be appended if it has content
            break
        else:
            current_labeled_message.append(f"{token}\t{label}")

    if current_labeled_message:
        labeled_data_conll.extend(current_labeled_message)
        labeled_data_conll.append("") # Add a blank line to separate sentences/messages in CoNLL

print("\n--- Manual Labeling Complete ---")
print(f"Total lines in CoNLL format (including blank lines): {len(labeled_data_conll)}")

# Save the labeled data to a plain text file
output_filename = "labeled_amharic_ner_data.conll"
with open(output_filename, "w", encoding="utf-8") as f:
    for line in labeled_data_conll:
        f.write(line + "\n")

print(f"\nLabeled data saved to {output_filename}")
# Out:
# NLTK 'punkt' data downloaded successfully.
# NLTK 'punkt_tab' data downloaded successfully.
#
# --- Starting Manual CoNLL Labeling for 50 Messages ---
# Instructions: For each token, provide its CoNLL label (B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O).
# Type 'done' when you are finished labeling a message. Type 'skip' to move to the next message.
# Example: 'ይህ B-Product ስልክ I-Product 5000 B-PRICE ብር I-PRICE ነው። O'
# DataFrame loaded successfully!
# Total messages: 1500
# First 5 rows of the DataFrame:
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7004
# 1  Zemen Express®    @ZemenExpress        7003
# 2  Zemen Express®    @ZemenExpress        7002
# 3  Zemen Express®    @ZemenExpress        7001
# 4  Zemen Express®    @ZemenExpress        7000
#
#                                              Message  \
# 0  Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አ...
#
#                         Date                 Media Path
# 0  2025-06-23 14:55:46+00:00  Photo attached (ID: 7004)
# 1  2025-06-23 14:55:40+00:00  Photo attached (ID: 7003)
# 2  2025-06-23 14:55:40+00:00  Photo attached (ID: 7002)
# 3  2025-06-23 14:55:40+00:00  Photo attached (ID: 7001)
# 4  2025-06-23 14:55:40+00:00  Photo attached (ID: 7000)
#
# --- Message 1 (ID: 7004) ---
# Original Message: Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አነስ ያለ ቦታ የማይዝ በኤሌክትሪክ የሚሰራ ሻይ፣ ቡና ለማፍላት የሚሆን ዋጋ፦ 1600 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Electric' -> Label: B-Product
# Token: 'Charcoal' -> Label: B-Product
# Token: 'Burner' -> Label: B-Product
# Token: 'በቀላሉ' -> Label: O
# Token: 'ከሰል' -> Label: B-Product
# Token: 'ለማያያዝ' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'አነስ' -> Label: O
# Token: 'ያለ' -> Label: O
# Token: 'ቦታ' -> Label: O
# Token: 'የማይዝ' -> Label: O
# Token: 'በኤሌክትሪክ' -> Label: I-Product
# Token: 'የሚሰራ' -> Label: O
# Token: 'ሻይ፣' -> Label: I-Product
# Token: 'ቡና' -> Label: I-Product
# Token: 'ለማፍላት' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'ዋጋ፦' -> Label: I-PRICE
# Token: '1600' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: I-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: B-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 2 (ID: 7003) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 3 (ID: 7002) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 4 (ID: 7001) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 5 (ID: 7000) ---
# Original Message: Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አነስ ያለ ቦታ የማይዝ በኤሌክትሪክ የሚሰራ ሻይ፣ ቡና ለማፍላት የሚሆን ዋጋ፦ 1600 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Electric' -> Label: B-Product
# Token: 'Charcoal' -> Label: I-Product
# Token: 'Burner' -> Label: I-Product
# Token: 'በቀላሉ' -> Label: O
# Token: 'ከሰል' -> Label: O
# Token: 'ለማያያዝ' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'አነስ' -> Label: O
# Token: 'ያለ' -> Label: O
# Token: 'ቦታ' -> Label: O
# Token: 'የማይዝ' -> Label: O
# Token: 'በኤሌክትሪክ' -> Label: O
# Token: 'የሚሰራ' -> Label: O
# Token: 'ሻይ፣' -> Label: O
# Token: 'ቡና' -> Label: O
# Token: 'ለማፍላት' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '1600' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: I-LOC
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 6 (ID: 6999) ---
# Original Message: Electric Charcoal Burner በቀላሉ ከሰል ለማያያዝ የሚሆን አነስ ያለ ቦታ የማይዝ በኤሌክትሪክ የሚሰራ ሻይ፣ ቡና ለማፍላት የሚሆን ዋጋ፦ 1600 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Electric' -> Label: B-LOC
# Token: 'Charcoal' -> Label: I-Product
# Token: 'Burner' -> Label: I-Product
# Token: 'በቀላሉ' -> Label: O
# Token: 'ከሰል' -> Label: O
# Token: 'ለማያያዝ' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'አነስ' -> Label: O
# Token: 'ያለ' -> Label: O
# Token: 'ቦታ' -> Label: O
# Token: 'የማይዝ' -> Label: O
# Token: 'በኤሌክትሪክ' -> Label: O
# Token: 'የሚሰራ' -> Label: O
# Token: 'ሻይ፣' -> Label: O
# Token: 'ቡና' -> Label: O
# Token: 'ለማፍላት' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '1600' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 7 (ID: 6998) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 8 (ID: 6997) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 9 (ID: 6996) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 10 (ID: 6995) ---
# Original Message: Food mould Tool ስድስት አይነት ቅርጽ ዋጋ፦ 700 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Food' -> Label: B-Product
# Token: 'mould' -> Label: I-Product
# Token: 'Tool' -> Label: I-Product
# Token: 'ስድስት' -> Label: O
# Token: 'አይነት' -> Label: O
# Token: 'ቅርጽ' -> Label: O
# Token: 'ዋጋ፦' -> Label: O
# Token: '700' -> Label: B-PRICE
# Token: 'ብር' -> Label: B-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 11 (ID: 6994) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 12 (ID: 6993) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 13 (ID: 6992) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 14 (ID: 6991) ---
# Original Message: Saachi Electric Kettle Borosilicate Glass Body Overheat protection Automatic switch off 2200w ዋጋ፦ 2700 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Saachi' -> Label: O
# Token: 'Electric' -> Label: I-Product
# Token: 'Kettle' -> Label: I-Product
# Token: 'Borosilicate' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'Borosilicate' -> Label: I-Product
# Token: 'Glass' -> Label: I-Product
# Token: 'Body' -> Label: I-Product
# Token: 'Overheat' -> Label: I-Product
# Token: 'protection' -> Label: I-Product
# Token: 'Automatic' -> Label: I-Product
# Token: 'switch' -> Label: I-Product
# Token: 'off' -> Label: I-Product
# Token: '2200w' -> Label: I-Product
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '2700' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 15 (ID: 6990) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 16 (ID: 6989) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 17 (ID: 6988) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 18 (ID: 6987) ---
# Original Message: 3pcs Bottle Stopper በማንኛውም ጠርሙስ ጫፍ የሚገጠም ለዘይት እና መሰል ነገሮች መቀነሻ የሚሆን በአግባቡ እየመጠንን ለመጠቀም ተመራጭ ዋጋ፦ 3ፍሬ 400 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: '3pcs' -> Label: B-Product
# Token: 'Bottle' -> Label: B-Product
# Token: 'Stopper' -> Label: B-Product
# Token: 'በማንኛውም' -> Label: O
# Token: 'ጠርሙስ' -> Label: O
# Token: 'ጫፍ' -> Label: O
# Token: 'የሚገጠም' -> Label: O
# Token: 'ለዘይት' -> Label: O
# Token: 'እና' -> Label: O
# Token: 'መሰል' -> Label: O
# Token: 'ነገሮች' -> Label: O
# Token: 'መቀነሻ' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'በአግባቡ' -> Label: O
# Token: 'እየመጠንን' -> Label: O
# Token: 'ለመጠቀም' -> Label: O
# Token: 'ተመራጭ' -> Label: O
# Token: 'ዋጋ፦' -> Label:  B-PRICE
# Token: '3ፍሬ' -> Label:  I-PRICE
# Token: '400' -> Label:  I-PRICE
# Token: 'ብር' -> Label:  I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 19 (ID: 6986) ---
# Original Message: 3pcs Bottle Stopper በማንኛውም ጠርሙስ ጫፍ የሚገጠም ለዘይት እና መሰል ነገሮች መቀነሻ የሚሆን በአግባቡ እየመጠንን ለመጠቀም ተመራጭ ዋጋ፦ 3ፍሬ 400 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: '3pcs' -> Label: B-Product
# Token: 'Bottle' -> Label: B-Product
# Token: 'Stopper' -> Label: I-Product
# Token: 'በማንኛውም' -> Label: O
# Token: 'ጠርሙስ' -> Label: O
# Token: 'ጫፍ' -> Label: O
# Token: 'የሚገጠም' -> Label: O
# Token: 'ለዘይት' -> Label: O
# Token: 'እና' -> Label: O
# Token: 'መሰል' -> Label: O
# Token: 'ነገሮች' -> Label: O
# Token: 'መቀነሻ' -> Label: O
# Token: 'የሚሆን' -> Label: O
# Token: 'በአግባቡ' -> Label: O
# Token: 'እየመጠንን' -> Label: O
# Token: 'ለመጠቀም' -> Label: O
# Token: 'ተመራጭ' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '3ፍሬ' -> Label: I-PRICE
# Token: '400' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: I-LOCO
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: O
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 20 (ID: 6985) ---
# Original Message: 1 pairs Sneaker Crease Protector ዋጋ፦ 400 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: '1' -> Label: O
# Token: 'pairs' -> Label: B-Product
# Token: 'Sneaker' -> Label: I-Product
# Token: 'Crease' -> Label: I-Product
# Token: 'Protector' -> Label: I-Product
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '400' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: I-PRICE
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 21 (ID: 6984) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 22 (ID: 6983) ---
# Original Message: 1 pairs Sneaker Crease Protector ዋጋ፦ 400 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: '1' -> Label: O
# Token: 'pairs' -> Label: B-Product
# Token: 'Sneaker' -> Label: B-Product
# Token: 'Crease' -> Label: B-Product
# Token: 'Protector' -> Label: I-Product
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '400' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 23 (ID: 6982) ---
# Original Message: Imitation Volcano Humidifier with LED Light በኤሌክትሪክየሚሰራ ለቤት መልካም መዓዛን የሚሰጥ ዋጋ፦ 1400 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Imitation' -> Label: B-Product
# Token: 'Volcano' -> Label: I-Product
# Token: 'Humidifier' -> Label: I-Product
# Token: 'with' -> Label: I-Product
# Token: 'LED' -> Label: I-Product
# Token: 'Light' -> Label: I-Product
# Token: 'በኤሌክትሪክየሚሰራ' -> Label: O
# Token: 'ለቤት' -> Label: O
# Token: 'መልካም' -> Label: O
# Token: 'መዓዛን' -> Label: O
# Token: 'የሚሰጥ' -> Label: O
# Token: 'ዋጋ፦' -> Label:  B-PRICE
# Token: '1400' -> Label:  I-PRICE
# Token: 'ብር' -> Label:  I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ያለን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: O
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 24 (ID: 6981) ---
# Original Message: Baby Carrier በፈለጉት አቅጣጫ ልጅዎን በምቾት ማዘል ያስችልዎታል ዋጋ፦ 2400 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Baby' -> Label: B-Product
# Token: 'Carrier' -> Label: I-Product
# Token: 'በፈለጉት' -> Label: O
# Token: 'አቅጣጫ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'አቅጣጫ' -> Label: O
# Token: 'ልጅዎን' -> Label: O
# Token: 'በምቾት' -> Label: O
# Token: 'ማዘል' -> Label: O
# Token: 'ያስችልዎታል' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '2400' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ፍሬ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 25 (ID: 6980) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 26 (ID: 6979) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 27 (ID: 6978) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 28 (ID: 6977) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 29 (ID: 6976) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 30 (ID: 6975) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 31 (ID: 6974) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 32 (ID: 6973) ---
# Original Message: Smart Usb Ultrasonic Car And Home Air Humidifier With Colorful Led Light Original Highquality በኤሌክትሪክ የሚሰራ ለቤትና ለመኪና መልካም መዓዛን የሚሰጥ Elevate the comfort level within your living premises with this fantastic Green Lion Air Mist Humidifier ዋጋ፦ 1100 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Smart' -> Label: B-Product
# Token: 'Usb' -> Label: I-Product
# Token: 'Ultrasonic' -> Label: I-Product
# Token: 'Car' -> Label: I-Product
# Token: 'And' -> Label: I-Product
# Token: 'Home' -> Label: I-Product
# Token: 'Air' -> Label: I-Product
# Token: 'Humidifier' -> Label: I-Product
# Token: 'With' -> Label: I-Product
# Token: 'Colorful' -> Label: I-Product
# Token: 'Led' -> Label: I-Product
# Token: 'Light' -> Label: I-Product
# Token: 'Original' -> Label: I-Product
# Token: 'Highquality' -> Label: I-Product
# Token: 'በኤሌክትሪክ' -> Label: O
# Token: 'የሚሰራ' -> Label: O
# Token: 'ለቤትና' -> Label: O
# Token: 'ለመኪና' -> Label: O
# Token: 'መልካም' -> Label: O
# Token: 'መዓዛን' -> Label: O
# Token: 'የሚሰጥ' -> Label: O
# Token: 'Elevate' -> Label: O
# Token: 'the' -> Label: O
# Token: 'comfort' -> Label: O
# Token: 'level' -> Label: O
# Token: 'within' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'within' -> Label: O
# Token: 'your' -> Label: O
# Token: 'living' -> Label: O
# Token: 'premises' -> Label: O
# Token: 'with' -> Label: O
# Token: 'this' -> Label: O
# Token: 'fantastic' -> Label: O
# Token: 'Green' -> Label: O
# Token: 'Lion' -> Label: O
# Token: 'Air' -> Label: O
# Token: 'Mist' -> Label: O
# Token: 'Humidifier' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '1100' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 33 (ID: 6972) ---
# Original Message: Smart Usb Ultrasonic Car And Home Air Humidifier With Colorful Led Light Original Highquality በኤሌክትሪክ የሚሰራ ለቤትና ለመኪና መልካም መዓዛን የሚሰጥ Elevate the comfort level within your living premises with this fantastic Green Lion Air Mist Humidifier ዋጋ፦ 1100 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Smart' -> Label: B-Product
# Token: 'Usb' -> Label: I-Product
# Token: 'Ultrasonic' -> Label: I-Product
# Token: 'Car' -> Label: I-Product
# Token: 'And' -> Label: I-Product
# Token: 'Home' -> Label: I-Product
# Token: 'Air' -> Label: I-Product
# Token: 'Humidifier' -> Label: I-Product
# Token: 'With' -> Label: I-Product
# Token: 'Colorful' -> Label: I-Product
# Token: 'Led' -> Label: I-Product
# Token: 'Light' -> Label: I-Product
# Token: 'Original' -> Label: I-Product
# Token: 'Highquality' -> Label: I-Product
# Token: 'በኤሌክትሪክ' -> Label: O
# Token: 'የሚሰራ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'የሚሰራ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'የሚሰራ' -> Label: O
# Token: 'ለቤትና' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ለቤትና' -> Label: O
# Token: 'ለመኪና' -> Label: O
# Token: 'መልካም' -> Label: O
# Token: 'መዓዛን' -> Label: O
# Token: 'የሚሰጥ' -> Label: O
# Token: 'Elevate' -> Label: O
# Token: 'the' -> Label: O
# Token: 'comfort' -> Label: O
# Token: 'level' -> Label: O
# Token: 'within' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'within' -> Label: O
# Token: 'your' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'your' -> Label: O
# Token: 'living' -> Label: O
# Token: 'premises' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'premises' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'premises' -> Label: O
# Token: 'with' -> Label: O
# Token: 'this' -> Label: O
# Token: 'fantastic' -> Label: O
# Token: 'Green' -> Label: O
# Token: 'Lion' -> Label: O
# Token: 'Air' -> Label: O
# Token: 'Mist' -> Label: O
# Token: 'Humidifier' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '1100' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: O
# Token: 'ገፃችን' -> Label: O
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 34 (ID: 6971) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 35 (ID: 6970) ---
# Original Message: Baby Head Helmet Cotton Walk Safety Hat Breathable Headgear Toddler Antifall Pad This product is made of nontoxic cotton material It can be adjustable to fits all the different size of head The product is also breathable and the babys head will not be sultry and muggy when playing ዋጋ፦ 550 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Baby' -> Label: B-Product
# Token: 'Head' -> Label: I-Product
# Token: 'Helmet' -> Label: I-Product
# Token: 'Cotton' -> Label: I-Product
# Token: 'Walk' -> Label: I-Product
# Token: 'Safety' -> Label: I-Product
# Token: 'Hat' -> Label: I-Product
# Token: 'Breathable' -> Label: I-Product
# Token: 'Headgear' -> Label: I-Product
# Token: 'Toddler' -> Label: I-Product
# Token: 'Antifall' -> Label: I-Product
# Token: 'Pad' -> Label: I-Product
# Token: 'This' -> Label: O
# Token: 'product' -> Label: O
# Token: 'is' -> Label: O
# Token: 'made' -> Label: O
# Token: 'of' -> Label: O
# Token: 'nontoxic' -> Label: O
# Token: 'cotton' -> Label: O
# Token: 'material' -> Label: O
# Token: 'It' -> Label: O
# Token: 'can' -> Label: O
# Token: 'be' -> Label: O
# Token: 'adjustable' -> Label: O
# Token: 'to' -> Label: O
# Token: 'fits' -> Label: O
# Token: 'all' -> Label: O
# Token: 'the' -> Label: O
# Token: 'different' -> Label: O
# Token: 'size' -> Label: O
# Token: 'of' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'of' -> Label: O
# Token: 'head' -> Label: O
# Token: 'The' -> Label: O
# Token: 'product' -> Label: O
# Token: 'is' -> Label: O
# Token: 'also' -> Label: O
# Token: 'breathable' -> Label: O
# Token: 'and' -> Label: O
# Token: 'the' -> Label: O
# Token: 'babys' -> Label: O
# Token: 'head' -> Label: O
# Token: 'will' -> Label: O
# Token: 'not' -> Label: O
# Token: 'be' -> Label: O
# Token: 'sultry' -> Label: O
# Token: 'and' -> Label: O
# Token: 'muggy' -> Label: O
# Token: 'when' -> Label: O
# Token: 'playing' -> Label: O
# Token: 'ዋጋ፦' -> Label: O
# Token: '550' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: O
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 36 (ID: 6969) ---
# Original Message: Baby Head Helmet Cotton Walk Safety Hat Breathable Headgear Toddler Antifall Pad This product is made of nontoxic cotton material It can be adjustable to fits all the different size of head The product is also breathable and the babys head will not be sultry and muggy when playing ዋጋ፦ 550 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Baby' -> Label: O
# Token: 'Head' -> Label: I-Product
# Token: 'Helmet' -> Label: I-Product
# Token: 'Cotton' -> Label: I-Product
# Token: 'Walk' -> Label: I-Product
# Token: 'Safety' -> Label: I-Product
# Token: 'Hat' -> Label: I-Product
# Token: 'Breathable' -> Label: I-Product
# Token: 'Headgear' -> Label: I-Product
# Token: 'Toddler' -> Label: I-Product
# Token: 'Antifall' -> Label: I-Product
# Token: 'Pad' -> Label: I-Product
# Token: 'This' -> Label: O
# Token: 'product' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'product' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'product' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'product' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'product' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'product' -> Label: O
# Token: 'is' -> Label: O
# Token: 'made' -> Label: O
# Token: 'of' -> Label: O
# Token: 'nontoxic' -> Label: O
# Token: 'cotton' -> Label: O
# Token: 'material' -> Label: O
# Token: 'It' -> Label: O
# Token: 'can' -> Label: O
# Token: 'be' -> Label: O
# Token: 'adjustable' -> Label: O
# Token: 'to' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'to' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'to' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'to' -> Label: O
# Token: 'fits' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'fits' -> Label: O
# Token: 'all' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'all' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'all' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'all' -> Label: O
# Token: 'the' -> Label: O
# Token: 'different' -> Label: O
# Token: 'size' -> Label: O
# Token: 'of' -> Label: O
# Token: 'head' -> Label: O
# Token: 'The' -> Label: O
# Token: 'product' -> Label: O
# Token: 'is' -> Label: O
# Token: 'also' -> Label: O
# Token: 'breathable' -> Label: O
# Token: 'and' -> Label: O
# Token: 'the' -> Label: O
# Token: 'babys' -> Label: O
# Token: 'head' -> Label: O
# Token: 'will' -> Label: O
# Token: 'not' -> Label: O
# Token: 'be' -> Label: O
# Token: 'sultry' -> Label: O
# Token: 'and' -> Label: O
# Token: 'muggy' -> Label: O
# Token: 'when' -> Label: O
# Token: 'playing' -> Label: O
# Token: 'ዋጋ፦' -> Label: O
# Token: '550' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: O
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 37 (ID: 6968) ---
# Original Message: በረፍት ቀንዎ ሱቅ ላይ መስተናገድ ለምትፈልጉ ውድ ደንበኞቻችን ነገ ከጠዋቱ 430 _ ቀኑ 1100 ድረስ ሱቃችን ክፍት ሁኖ ይጠብቅዎታል ሱቅ መተው መግዛት ላልቻላችሁ በሞተረኞች ያሉበት እናደርሳለን ዘወትር ሰኞ _ቅዳሜ ከጠዋቱ 230 እስከ ምሽቱ 200 ድረስ ክፍት መሆኑን እንገልፃለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'በረፍት' -> Label: O
# Token: 'ቀንዎ' -> Label: O
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ሱቅ' -> Label: O
# Token: 'ላይ' -> Label: O
# Token: 'መስተናገድ' -> Label: O
# Token: 'ለምትፈልጉ' -> Label: O
# Token: 'ውድ' -> Label: O
# Token: 'ደንበኞቻችን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ደንበኞቻችን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ደንበኞቻችን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ደንበኞቻችን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ደንበኞቻችን' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ደንበኞቻችን' -> Label: O
# Token: 'ነገ' -> Label: O
# Token: 'ከጠዋቱ' -> Label: O
# Token: '430' -> Label: O
# Token: '_' -> Label: OO
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: '_' -> Label: O
# Token: 'ቀኑ' -> Label: O
# Token: '1100' -> Label: O
# Token: 'ድረስ' -> Label: O
# Token: 'ሱቃችን' -> Label: O
# Token: 'ክፍት' -> Label: O
# Token: 'ሁኖ' -> Label: O
# Token: 'ይጠብቅዎታል' -> Label: O
# Token: 'ሱቅ' -> Label: O
# Token: 'መተው' -> Label: O
# Token: 'መግዛት' -> Label: O
# Token: 'ላልቻላችሁ' -> Label: O
# Token: 'በሞተረኞች' -> Label: O
# Token: 'ያሉበት' -> Label: O
# Token: 'እናደርሳለን' -> Label: O
# Token: 'ዘወትር' -> Label: O
# Token: 'ሰኞ' -> Label: O
# Token: '_ቅዳሜ' -> Label: O
# Token: 'ከጠዋቱ' -> Label: O
# Token: '230' -> Label: O
# Token: 'እስከ' -> Label: O
# Token: 'ምሽቱ' -> Label: O
# Token: '200' -> Label: O
# Token: 'ድረስ' -> Label: O
# Token: 'ክፍት' -> Label: O
# Token: 'መሆኑን' -> Label: O
# Token: 'እንገልፃለን' -> Label: O
# Token: 'አድራሻ' -> Label: O
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: O
# Token: 'ቢሮ' -> Label: O
# Token: 'ቁ' -> Label: O
# Token: 'S05S06' -> Label: O
# Token: '0902660722' -> Label: O
# Token: '0928460606' -> Label: O
# Token: 'በTelegram' -> Label: O
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: O
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: O
# Token: 'ገፃችን' -> Label: O
# Token: 'httpstelegrammezemenexpress' -> Label: O
#
# --- Message 38 (ID: 6967) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 39 (ID: 6966) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'nan' -> Label: O
#
# --- Message 40 (ID: 6965) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 41 (ID: 6964) ---
# Original Message: Baby knee socks ልጅዎ መዳህ በሚጀምሩበት ጊዜ ተመራጭ ዋጋ፦ 250 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Baby' -> Label: B-Product
# Token: 'knee' -> Label: I-Product
# Token: 'socks' -> Label: I-Product
# Token: 'ልጅዎ' -> Label: O
# Token: 'መዳህ' -> Label: O
# Token: 'በሚጀምሩበት' -> Label: O
# Token: 'ጊዜ' -> Label: O
# Token: 'ተመራጭ' -> Label: O
# Token: 'ዋጋ፦' -> Label: O
# Token: '250' -> Label: B-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: I-PRICE
# Token: 'ፍሬ' -> Label: I-PRICE
# Token: 'ነው' -> Label: IO-PRICE
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'አድራሻ' -> Label: I-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: O
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 42 (ID: 6963) ---
# Original Message: Baby knee socks ልጅዎ መዳህ በሚጀምሩበት ጊዜ ተመራጭ ዋጋ፦ 250 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'Baby' -> Label: O
# Token: 'knee' -> Label: I-Product
# Token: 'socks' -> Label: I-Product
# Token: 'ልጅዎ' -> Label: O
# Token: 'መዳህ' -> Label: O
# Token: 'በሚጀምሩበት' -> Label: O
# Token: 'ጊዜ' -> Label: O
# Token: 'ተመራጭ' -> Label: O
# Token: 'ዋጋ፦' -> Label: O
# Token: '250' -> Label: I-LOC
# Token: 'ብር' -> Label: I-LOC
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: O
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 43 (ID: 6962) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 44 (ID: 6961) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 45 (ID: 6960) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 46 (ID: 6959) ---
# Original Message: 5in1 Trouser Hanger የሱሪ ማስቀመጫ ዋጋ፦ 650 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: '5in1' -> Label: O
# Token: 'Trouser' -> Label: B-Product
# Token: 'Hanger' -> Label: I-Product
# Token: 'የሱሪ' -> Label: O
# Token: 'ማስቀመጫ' -> Label: O
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '650' -> Label: I-PRICE
# Token: 'ብር' -> Label: I-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label: O
# Token: 'ያለን' -> Label: O
# Token: 'አድራሻ' -> Label: O
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: O
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: O
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Message 47 (ID: 6953) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 48 (ID: 6952) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 49 (ID: 6951) ---
# Original Message: nan
#
# Tokens and their labels:
# Token: 'nan' -> Label: O
#
# --- Message 50 (ID: 6950) ---
# Original Message: WaterProof Shower Cap reusable ዋጋ፦ 200 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ ቢሮ ቁ S05S06 0902660722 0928460606 በTelegram ለማዘዝ ይጠቀሙ zemencallcenter zemenexpressadmin ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን httpstelegrammezemenexpress
#
# Tokens and their labels:
# Token: 'WaterProof' -> Label: B-Product
# Token: 'Shower' -> Label: I-Product
# Token: 'Cap' -> Label: I-Product
# Token: 'reusable' -> Label: I-Product
# Token: 'ዋጋ፦' -> Label: B-PRICE
# Token: '200' -> Label: B-PRICE
# Token: 'ብር' -> Label: B-PRICE
# Token: 'ውስን' -> Label: O
# Token: 'ፍሬ' -> Label: O
# Token: 'ነው' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ነው' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ነው' -> Label: O
# Token: 'ያለው' -> Label: O
# Token: 'አድራሻ' -> Label: B-LOC
# Token: 'መገናኛ_መሰረት_ደፋር_ሞል_ሁለተኛ_ፎቅ' -> Label: I-LOC
# Token: 'ቢሮ' -> Label: I-LOC
# Token: 'ቁ' -> Label: I-LOC
# Token: 'S05S06' -> Label: I-LOC
# Token: '0902660722' -> Label: I-LOC
# Token: '0928460606' -> Label:
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: '0928460606' -> Label: I-LOC
# Token: 'በTelegram' -> Label: I-LOC
# Token: 'ለማዘዝ' -> Label: O
# Token: 'ይጠቀሙ' -> Label: O
# Token: 'zemencallcenter' -> Label: I-LOC
# Token: 'zemenexpressadmin' -> Label: I-LOC
# Token: 'ለተጨማሪ' -> Label: O
# Token: 'ማብራሪያ' -> Label: O
# Token: 'የቴሌግራም' -> Label: I-LOC
# Token: 'ገፃችን' -> Label: V
# Invalid label. Please use one of: B-Product, I-Product, B-LOC, I-LOC, B-PRICE, I-PRICE, O, skip, done
# Token: 'ገፃችን' -> Label: I-LOC
# Token: 'httpstelegrammezemenexpress' -> Label: I-LOC
#
# --- Manual Labeling Complete ---
# Total lines in CoNLL format (including blank lines): 922
#
# Labeled data saved to labeled_amharic_ner_data.conll
